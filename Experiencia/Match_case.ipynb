# %% [markdown]
# Actividad:
# Usar match-case con la última versión de su calculadora. Ayuda: usarla dentro de la función de validadción llamada: "procesar_y_mostrar_operación()"
# Incluir un mensaje para opción válida (se maneja un caso por defecto en el match-case. Buscar en https://www.w3schools.com/python/python_match.asp)
# Además explorar la pagina https://www.w3schools.com/python/
# whiles vs for
# e inventarse cuatro ejemplos de cada una
# Actividad en clase hasta las 9:15 pm

# %%
# Importando la Libreria/biblioteca de matemáticas de Python
import math

# DEFINICION DE LAS FUNCIONES:
def mostrar_título():
    print('Ejemplo Calculadora Sencilla (+,-,*,/):')

def mostrar_menu():
    print()
    print("MENU:")
    print("0: Salir")
    print("1: Sumar (+)")
    print("2: Restar (-)")
    print("3: Multiplicar (*)")
    print("4: Dividir (/)")
    print("5: Logaritmo (log10)")
    print("6: Coseno (cos)")
    print("7: Tangente (tan)")
    print("8: Seno (sen)")
    print("9: potenciacion (x^y)")
    print("10: raiz cuadrada")
    print()

def ingresar_datos():
    opcion = input("Ingrese la opción deseada del menú: ")

    # si elige salir, no pido números
    if opcion == "0":
        return opcion, None, None

    numero_uno = float(input("Ingrese el primer número de la operación: "))
    numero_dos = float(input("Ingrese el segundo número de la operación: "))
    return opcion, numero_uno, numero_dos

# FUNCIONES DE OPERACIONES
def calcular_suma(a, b): return a + b
def calcular_resta(a, b): return a - b
def calcular_multiplicacion(a, b): return a * b
def calcular_division(a, b): return a / b
def calcular_logaritmo_base10(x): return math.log10(x)
def calcular_coseno(x): return math.cos(x)
def calcular_tangente(x): return math.tan(x)
def calcular_seno(x): return math.sin(x)
def calcular_potenciacion(x): return x**2
def calcular_raiz_cuadrada(x): return math.sqrt(x)

def procesar_y_mostrar_operacion(opcion, numero_uno, numero_dos):
    if opcion == "1":
        print("Resultado:", calcular_suma(numero_uno, numero_dos))
    elif opcion == "2":
        print("Resultado:", calcular_resta(numero_uno, numero_dos))
    elif opcion == "3":
        print("Resultado:", calcular_multiplicacion(numero_uno, numero_dos))
    elif opcion == "4":
        if numero_dos != 0:
            print("Resultado:", calcular_division(numero_uno, numero_dos))
        else:
            print("¡No es posible dividir entre cero!")
    elif opcion == "5":
        print("Resultado1:", calcular_logaritmo_base10(numero_uno))
        print("Resultado2:", calcular_logaritmo_base10(numero_dos))
    elif opcion == "6":
        print("Resultado1:", calcular_coseno(numero_uno))
        print("Resultado2:", calcular_coseno(numero_dos))
    elif opcion == "7":
        print("Resultado1:", calcular_tangente(numero_uno))
        print("Resultado2:", calcular_tangente(numero_dos))
    elif opcion == "8":
        print("Resultado1:", calcular_seno(numero_uno))
        print("Resultado2:", calcular_seno(numero_dos))
    elif opcion == "9":
        print("Resultado1:", calcular_potenciacion(numero_uno))
        print("Resultado2:", calcular_potenciacion(numero_dos))
    elif opcion == "10":
        print("Resultado1:", calcular_raiz_cuadrada(numero_uno))
        print("Resultado2:", calcular_raiz_cuadrada(numero_dos))
    else:
        print("Opción no válida.")

def llamar_funciones():
    mostrar_título()
    while True:  # bucle principal
        mostrar_menu()
        opcion, numero_uno, numero_dos = ingresar_datos()

        if opcion == "0":
            print("¡Hasta luego!")
            break  # salimos del bucle y termina el programa

        procesar_y_mostrar_operacion(opcion, numero_uno, numero_dos)

# EJECUCION DEL PROGRAMA:
llamar_funciones()

# %%
opcion = int(input("Ingrese la opción del menu:"))
match opcion:
  case 1:
    print("Sumar")
  case 2:
    print("Restar")
  case 3:
    print("Wednesday")
  case 4:
    print("Thursday")
  case 5:
    print("Friday")
  case 6:
    print("Saturday")
  case 7:
    print("Sunday")
  case 8:
    print("Sunday")
  case 9:
    print("Seno")
  case 10:
    print("Tangente")
  case 11:
    print("Salir")

# %%
# Importando la Libreria/biblioteca de matemáticas de Python
import math

# DEFINICION DE LAS FUNCIONES:
def mostrar_título():
    print('Ejemplo Calculadora Sencilla (+,-,*,/):')

def mostrar_menu():
    print()
    print("MENU:")
    print("0: Salir")
    print("1: Sumar (+)")
    print("2: Restar (-)")
    print("3: Multiplicar (*)")
    print("4: Dividir (/)")
    print("5: Logaritmo (log10)")
    print("6: Coseno (cos)")
    print("7: Tangente (tan)")
    print("8: Seno (sen)")
    print("9: potenciacion (x^y)")
    print("10: raiz cuadrada")
    print()

def ingresar_datos():
    opcion = input("Ingrese la opción deseada del menú: ")

    # si elige salir, no pido números
    if opcion == "0":
        return opcion, None, None
    if opcion >= "10" or opcion < "0":
        return opcion, None, None

    numero_uno = float(input("Ingrese el primer número de la operación: "))
    numero_dos = float(input("Ingrese el segundo número de la operación: "))
    return opcion, numero_uno, numero_dos

# FUNCIONES DE OPERACIONES
def calcular_suma(a, b): return a + b
def calcular_resta(a, b): return a - b
def calcular_multiplicacion(a, b): return a * b
def calcular_division(a, b): return a / b
def calcular_logaritmo_base10(x): return math.log10(x)
def calcular_coseno(x): return math.cos(x)
def calcular_tangente(x): return math.tan(x)
def calcular_seno(x): return math.sin(x)
def calcular_potenciacion(x): return x**2
def calcular_raiz_cuadrada(x): return math.sqrt(x)

def procesar_y_mostrar_operacion(opcion, numero_uno, numero_dos):
    match opcion:
        case "1":
            print("Resultado:", calcular_suma(numero_uno, numero_dos))
        case "2":
            print("Resultado:", calcular_resta(numero_uno, numero_dos))
        case "3":
            print("Resultado:", calcular_multiplicacion(numero_uno, numero_dos))
        case "4":
            if numero_dos != 0:
                print("Resultado:", calcular_division(numero_uno, numero_dos))
            else:
                print("¡No es posible dividir entre cero!")
        case "5":
            print("Resultado1:", calcular_logaritmo_base10(numero_uno))
            print("Resultado2:", calcular_logaritmo_base10(numero_dos))
        case "6":
            print("Resultado1:", calcular_coseno(numero_uno))
            print("Resultado2:", calcular_coseno(numero_dos))
        case "7":
            print("Resultado1:", calcular_tangente(numero_uno))
            print("Resultado2:", calcular_tangente(numero_dos))
        case "8":
            print("Resultado1:", calcular_seno(numero_uno))
            print("Resultado2:", calcular_seno(numero_dos))
        case "9":
            print("Resultado1:", calcular_potenciacion(numero_uno))
            print("Resultado2:", calcular_potenciacion(numero_dos))
        case "10":
            print("Resultado1:", calcular_raiz_cuadrada(numero_uno))
            print("Resultado2:", calcular_raiz_cuadrada(numero_dos))
        case _:
            print("Opción no válida.")

def llamar_funciones():
    mostrar_título()
    while True:  # bucle principal
        mostrar_menu()
        opcion, numero_uno, numero_dos = ingresar_datos()

        if opcion == "0":
            print("¡Hasta luego!")
            break  # salimos del bucle y termina el programa

        procesar_y_mostrar_operacion(opcion, numero_uno, numero_dos)

# EJECUCION DEL PROGRAMA:
llamar_funciones()
# Out:
# Ejemplo Calculadora Sencilla (+,-,*,/):
#
# MENU:
# 0: Salir
# 1: Sumar (+)
# 2: Restar (-)
# 3: Multiplicar (*)
# 4: Dividir (/)
# 5: Logaritmo (log10)
# 6: Coseno (cos)
# 7: Tangente (tan)
# 8: Seno (sen)
# 9: potenciacion (x^y)
# 10: raiz cuadrada
#
# Ingrese la opción deseada del menú: -8
# Opción no válida.
#
# MENU:
# 0: Salir
# 1: Sumar (+)
# 2: Restar (-)
# 3: Multiplicar (*)
# 4: Dividir (/)
# 5: Logaritmo (log10)
# 6: Coseno (cos)
# 7: Tangente (tan)
# 8: Seno (sen)
# 9: potenciacion (x^y)
# 10: raiz cuadrada
#
# Ingrese la opción deseada del menú: a
# Opción no válida.
#
# MENU:
# 0: Salir
# 1: Sumar (+)
# 2: Restar (-)
# 3: Multiplicar (*)
# 4: Dividir (/)
# 5: Logaritmo (log10)
# 6: Coseno (cos)
# 7: Tangente (tan)
# 8: Seno (sen)
# 9: potenciacion (x^y)
# 10: raiz cuadrada
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1552255362.py in <cell line: 0>()
#      94
#      95 # EJECUCION DEL PROGRAMA:
# ---> 96 llamar_funciones()
#
# /tmp/ipython-input-1552255362.py in llamar_funciones()
#      85     while True:  # bucle principal
#      86         mostrar_menu()
# ---> 87         opcion, numero_uno, numero_dos = ingresar_datos()
#      88
#      89         if opcion == "0":
#
# /tmp/ipython-input-1552255362.py in ingresar_datos()
#      23
#      24 def ingresar_datos():
# ---> 25     opcion = input("Ingrese la opción deseada del menú: ")
#      26
#      27     # si elige salir, no pido números
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
